# %% [markdown]
# # Frequency of a pendulum
# ```
# 2018/11/30
# 407B at AISVN
# ```
# ## Setup
# To investigate the dependency of the we ...
#
# $$T\approx 2\pi \sqrt{\frac{L}{g}}$$
#
# Here is our data

# %%
import pandas as pd
length_period_2018_11-30 - csv = pd.read_csv("../input/length-period_2018-11-30 - csv.csv")

# %% [markdown]
# Now lets ...
